# %% [markdown]
# <a href="https://colab.research.google.com/github/04-AhmadThariqRamadhan/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MODUL 2 – Penggunaan Numpy dan OpenCV serta Pengenalan Aplikasi-aplikasi Pengolahan Citra

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/images/ok.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/images/ok.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/images/ok.jpg', img5)

#tampilan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# #Pertanyaan
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# - Perbedaannya jika menggunakan matplotlib rentang pixelnya akan ditampilkan.
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# - Terdapat perbedaan pada rentang nilai yang dapat ditampung oleh tipe data tersebut. int32 rentang nilai yang dapat ditampung jauh lebih besar daripada int16
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode (di soal)
# - Untuk bertujuan memberikan perintah untuk untuk mengimpor fungsi cv2_imshow dari library google.colab.patches.
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
# - Bertujuan untuk memberikan perintah untuk mengimpor modul io dari library scikit-image.

# %% [markdown]
# #E. TUGAS

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?

# %% [markdown]
# - Akan Berubah

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
img_rb = img.copy()
b, g, r = cv.split(img)
img_rb = cv.merge([r, b, b])
plt.imshow(img_rb)
plt.show()

# %%
img_rb = img.copy()
b, g, r = cv.split(img)
img_rb = cv.merge([g, b, b])
plt.imshow(img_rb)
plt.show()

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
imgt = img[20:115,25:120]
plt.imshow(imgt)

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
img_rb = img.copy()
b, g, r = cv.split(img)
red_channel = r
img_red = cv.merge([red_channel, red_channel, red_channel])
plt.imshow(img_red[5:30], cmap='gray')
plt.show()

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
img_rb = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img_rb, pt1=(354,0), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_rb, pt1=(200,250), pt2=(510,150), color=(0,255,0), thickness=10)
cv.rectangle(img_rb, pt1=(500,500), pt2=(400,100), color=(255,255,255), thickness=10)
cv.rectangle(img_rb, pt1=(200,450), pt2=(600,550), color=(255,0,0), thickness=10)
cv.rectangle(img_rb, pt1=(200,100), pt2=(400,600), color=(0,0,255), thickness=10)

plt.imshow(img_rb)

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
imgFlip = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
plt.imshow(imgFlip)

# %% [markdown]
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
image1 = cv.imread('/content/drive/MyDrive/images/saitama.jpg')
image2 = cv.cvtColor(image1, cv.COLOR_BGR2RGB)

cv.rectangle(image2, pt1=(2200,500), pt2 = (2000,340), color= (225,0,255), thickness=30)
cv.circle(image2, center=(2100,440),radius=55, color= (255,0,0), thickness=10)

plt.imshow(image2)

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.

# %%
font  = cv.FONT_HERSHEY_TRIPLEX

img12 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

cv.rectangle(img12,pt1=(0,700),pt2=(100,550),color=(0,255,255),thickness=10)
cv.putText(img12, text="SAITAMA NI BUOS", org=(250,200), fontFace=font, fontScale=2, color =(255,0,0),thickness = 5, lineType = cv.LINE_AA)

plt.imshow(img12)

# %% [markdown]
# 10. Tunjukkan code program anda pada bapak/ibu dosen
